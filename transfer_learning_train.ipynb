# %%
#@title NVIDIA GPU check
# !nvidia-smi
# Out:
# Mon Jan  8 16:49:36 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
#@title clone the model repo
# !git clone --depth 1 https://github.com/asigalov61/Tiny-Music-Transformer
# Out:
# Cloning into 'Tiny-Music-Transformer'...
# remote: Enumerating objects: 29, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 29 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (29/29), 1.01 MiB | 9.43 MiB/s, done.

# %%
# Install dependencies

# !pip install huggingface_hub torch einops torch-summary tqdm matplotlib
# !apt install fluidsynth

# Import modules
import os
import random
import torch
from torch.utils.data import DataLoader, Dataset
from torchsummary import summary
import matplotlib.pyplot as plt
import tqdm
from huggingface_hub import hf_hub_download
# Out:
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (0.20.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.1.0+cu121)
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (0.7.0)
# Requirement already satisfied: torch-summary in /usr/local/lib/python3.10/dist-packages (1.4.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (23.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fluidsynth is already the newest version (2.2.5-1).
# 0 upgraded, 0 newly installed, 0 to remove and 24 not upgraded.

# %%
# %cd /content/Tiny-Music-Transformer
from x_transformer_1_23_2 import TransformerWrapper, AutoregressiveWrapper, Decoder
import TMIDIX
#from midi_to_colab_audio import midi_to_colab_audio
# Out:
# /content/Tiny-Music-Transformer

# %%
#@title Load TMIDIX MIDI Processor

print('Loading TMIDIX MIDI Processor...')

def TMIDIX_MIDI_Processor(midi_file):

    melody_chords = []

    try:
        fn = os.path.basename(midi_file)

        # Filtering out GIANT4 MIDIs
        file_size = os.path.getsize(midi_file)

        if file_size <= 1000000:

          score = TMIDIX.midi2single_track_ms_score(open(midi_file, 'rb').read(),
                                          recalculate_channels=False)

          enhanced_score = TMIDIX.advanced_score_processor(score,
                                                          return_score_analysis=False,
                                                          return_enhanced_score_notes=True)[0]

          if len(enhanced_score) > 0:
              if min([e[1] for e in enhanced_score]) >= 0 and min([e[2] for e in enhanced_score]) >= 0:

                  if len(enhanced_score) > 0:

                      for e in enhanced_score:
                        e[1] = int(e[1] / 16)
                        e[2] = int(e[2] / 16)

                      # Sorting by patch, pitch, then by start-time

                      enhanced_score.sort(key=lambda x: x[6])
                      enhanced_score.sort(key=lambda x: x[4], reverse=True)
                      enhanced_score.sort(key=lambda x: x[1])

                      pe = enhanced_score[0]

                      notes = []

                      for e in enhanced_score:

                        time = max(0, min(127, (e[1] - pe[1])))
                        dur = max(0, min(127, e[2]))
                        cha = max(0, min(15, e[3]))
                        ptc = max(1, min(127, e[4]))

                        notes.append([time, dur, cha, ptc])

                        pe = e

                      return notes

    except Exception as e:
      print('Error!')
      print('Exception', e)
      return None

print('Done!')
# Out:
# Loading TMIDIX MIDI Processor...
# Done!

# %%
# !wget 'https://storage.googleapis.com/magentadata/datasets/maestro/v3.0.0/maestro-v3.0.0-midi.zip'
# !unzip 'maestro-v3.0.0-midi.zip' -d '/content/Tiny-Music-Transformer/maestro_dataset_v3'
# Out:
# --2024-01-08 16:58:32--  https://storage.googleapis.com/magentadata/datasets/maestro/v3.0.0/maestro-v3.0.0-midi.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 108.177.119.207, 108.177.127.207, 172.217.218.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|108.177.119.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 58416533 (56M) [application/octet-stream]
# Saving to: ‘maestro-v3.0.0-midi.zip’
#
# maestro-v3.0.0-midi 100%[===================>]  55.71M  28.6MB/s    in 2.0s
#
# 2024-01-08 16:58:34 (28.6 MB/s) - ‘maestro-v3.0.0-midi.zip’ saved [58416533/58416533]
#
# Archive:  maestro-v3.0.0-midi.zip
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_08_R1_2004_01-02_ORIG_MID--AUDIO_08_R1_2004_01_Track01_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_09_R1_2004_05_ORIG_MID--AUDIO_09_R1_2004_06_Track06_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_14_R1_2004_01-03_ORIG_MID--AUDIO_14_R1_2004_01_Track01_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_01_R1_2004_01-02_ORIG_MID--AUDIO_01_R1_2004_03_Track03_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_13_01_2004_01-05_ORIG_MID--AUDIO_13_R1_2004_09_Track09_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_18_R1_2004_01-02_ORIG_MID--AUDIO_18_R1_2004_03_Track03_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_19_R1_2004_01-02_ORIG_MID--AUDIO_19_R1_2004_01_Track01_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_04_R1_2004_06_ORIG_MID--AUDIO_04_R1_2004_08_Track08_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_22_R2_2004_01_ORIG_MID--AUDIO_22_R2_2004_01_Track01_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_04_R1_2004_03-05_ORIG_MID--AUDIO_04_R1_2004_04_Track04_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_14_R2_2004_01_ORIG_MID--AUDIO_14_R2_2004_01_Track01_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_19_R1_2004_01-02_ORIG_MID--AUDIO_19_R1_2004_02_Track02_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_16_R1_2004_01-08_ORIG_MID--AUDIO_16_R1_2004_04_Track04_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_10_R1_2004_01-02_ORIG_MID--AUDIO_10_R1_2004_02_Track02_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_05_R1_2004_02-03_ORIG_MID--AUDIO_05_R1_2004_06_Track06_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_14_R2_2004_01_ORIG_MID--AUDIO_14_R2_2004_04_Track04_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_12_01_2004_01-05_ORIG_MID--AUDIO_12_R1_2004_07_Track07_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_06_R2_2004_01_ORIG_MID--AUDIO_06_R2_2004_03_Track03_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_12_01_2004_01-05_ORIG_MID--AUDIO_12_R1_2004_09_Track09_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_11_R1_2004_01-02_ORIG_MID--AUDIO_11_R1_2004_02_Track02_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_12_01_2004_01-05_ORIG_MID--AUDIO_12_R1_2004_03_Track03_wav--1.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_06_R2_2004_01_ORIG_MID--AUDIO_06_R2_2004_02_Track02_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_07_R1_2004_01_ORIG_MID--AUDIO_07_R1_2004_02_Track02_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_16_R1_2004_01-08_ORIG_MID--AUDIO_16_R1_2004_03_Track03_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_19_R2_2004_01_ORIG_MID--AUDIO_19_R2_2004_03_Track03_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_15_R2_2004_01_ORIG_MID--AUDIO_15_R2_2004_01_Track01_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_16_R2_2004_01_ORIG_MID--AUDIO_16_R2_2004_01_Track01_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_17_R1_2004_01-03_ORIG_MID--AUDIO_17_R1_2004_02_Track02_wav--2.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_04_R1_2004_01-02_ORIG_MID--AUDIO_04_R1_2004_01_Track01_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_13_01_2004_01-05_ORIG_MID--AUDIO_13_R1_2004_12_Track12_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_07_R1_2004_01_ORIG_MID--AUDIO_07_R1_2004_04_Track04_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_08_R1_2004_01-02_ORIG_MID--AUDIO_08_R1_2004_02_Track02_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_16_R1_2004_01-08_ORIG_MID--AUDIO_16_R1_2004_13_Track13_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_17_R2_2004_01_ORIG_MID--AUDIO_17_R2_2004_02_Track02_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_15_R2_2004_01_ORIG_MID--AUDIO_15_R2_2004_04_Track04_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_16_R2_2004_01_ORIG_MID--AUDIO_16_R2_2004_02_Track02_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_15_R2_2004_01_ORIG_MID--AUDIO_15_R2_2004_02_Track02_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_04_R1_2004_01-02_ORIG_MID--AUDIO_04_R1_2004_02_Track02_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_20_R2_2004_01_ORIG_MID--AUDIO_20_R1_2004_01_Track01_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_18_R1_2004_01-02_ORIG_MID--AUDIO_18_R1_2004_02_Track02_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_22_R1_2004_01-04_ORIG_MID--AUDIO_22_R1_2004_17_Track17_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_15_R1_2004_04_ORIG_MID--AUDIO_15_R1_2004_04_Track04_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_08_R1_2004_04-06_ORIG_MID--AUDIO_08_R1_2004_05_Track05_wav--2.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_01_R1_2004_01-02_ORIG_MID--AUDIO_01_R1_2004_02_Track02_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_11_R1_2004_01-02_ORIG_MID--AUDIO_11_R1_2004_01_Track01_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_10_R1_2004_01-02_ORIG_MID--AUDIO_10_R1_2004_01_Track01_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_22_R1_2004_01-04_ORIG_MID--AUDIO_22_R1_2004_10_Track10_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_13_01_2004_01-05_ORIG_MID--AUDIO_13_R1_2004_08_Track08_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_22_R1_2004_01-04_ORIG_MID--AUDIO_22_R1_2004_03_Track03_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_13_01_2004_01-05_ORIG_MID--AUDIO_13_R1_2004_10_Track10_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_01_R1_2004_03_ORIG_MID--AUDIO_01_R1_2004_04_Track04_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_06_R2_2004_01_ORIG_MID--AUDIO_06_R2_2004_01_Track01_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_02_R1_2004_01-05_ORIG_MID--AUDIO_02_R1_2004_06_Track06_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_17_R1_2004_03-06_ORIG_MID--AUDIO_20_R2_2004_12_Track12_wav--1.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_18_R1_2004_04_ORIG_MID--AUDIO_18_R1_2004_07_Track07_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_19_R2_2004_01_ORIG_MID--AUDIO_19_R2_2004_01_Track01_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_15_R1_2004_03_ORIG_MID--AUDIO_15_R1_2004_03_Track03_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_07_R1_2004_01_ORIG_MID--AUDIO_07_R1_2004_12_Track12_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_08_R1_2004_03_ORIG_MID--AUDIO_08_R1_2004_03_Track03_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_04_R2_2004_01_ORIG_MID--AUDIO_04_R2_2004_02_Track02_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_09_R1_2004_01-02_ORIG_MID--AUDIO_09_R1_2004_02_Track02_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_15_R2_2004_01_ORIG_MID--AUDIO_15_R2_2004_03_Track03_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_17_R1_2004_01-03_ORIG_MID--AUDIO_17_R1_2004_03_Track03_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_22_R2_2004_01_ORIG_MID--AUDIO_22_R2_2004_04_Track04_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_17_R1_2004_04_ORIG_MID--AUDIO_17_R1_2004_09_Track09_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_04_R2_2004_01_ORIG_MID--AUDIO_04_R2_2004_01_Track01_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_08_R1_2004_04-06_ORIG_MID--AUDIO_08_R1_2004_05_Track05_wav--1.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_09_R1_2004_05_ORIG_MID--AUDIO_09_R1_2004_08_Track08_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_06_R1_2004_01_ORIG_MID--AUDIO_06_R1_2004_01_Track01_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_17_R1_2004_01-02_ORIG_MID--AUDIO_20_R2_2004_06_Track06_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_21_R1_2004_03_ORIG_MID--AUDIO_21_R1_2004_04_Track04_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_21_R1_2004_02_ORIG_MID--AUDIO_21_R1_2004_03_Track03_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_07_R1_2004_01_ORIG_MID--AUDIO_07_R1_2004_06_Track06_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_16_R2_2004_01_ORIG_MID--AUDIO_16_R2_2004_04_Track04_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_19_R2_2004_01_ORIG_MID--AUDIO_19_R2_2004_02_Track02_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_17_R2_2004_01_ORIG_MID--AUDIO_17_R2_2004_03_Track03_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_17_R1_2004_01-02_ORIG_MID--AUDIO_20_R2_2004_04_Track04_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_09_R1_2004_01-02_ORIG_MID--AUDIO_09_R1_2004_01_Track01_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_14_R1_2004_04_ORIG_MID--AUDIO_14_R1_2004_04_Track04_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_18_R1_2004_01-02_ORIG_MID--AUDIO_18_R1_2004_04_Track04_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_02_R1_2004_01-05_ORIG_MID--AUDIO_02_R1_2004_10_Track10_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_10_R1_2004_05_ORIG_MID--AUDIO_10_R1_2004_05_Track05_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_16_R2_2004_01_ORIG_MID--AUDIO_16_R2_2004_03_Track03_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_16_R1_2004_01-08_ORIG_MID--AUDIO_16_R1_2004_08_Track08_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_17_R1_2004_03-06_ORIG_MID--AUDIO_20_R2_2004_08_Track08_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_02_R1_2004_01-05_ORIG_MID--AUDIO_02_R1_2004_05_Track05_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_17_R1_2004_01-02_ORIG_MID--AUDIO_20_R2_2004_02_Track02_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_02_R1_2004_01-05_ORIG_MID--AUDIO_02_R1_2004_08_Track08_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_16_R1_2004_01-08_ORIG_MID--AUDIO_16_R1_2004_02_Track02_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_10_R1_2004_03-04_ORIG_MID--AUDIO_10_R1_2004_03_Track03_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_21_R1_2004_01_ORIG_MID--AUDIO_21_R1_2004_01_Track01_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_05_R1_2004_01_ORIG_MID--AUDIO_05_R1_2004_03_Track03_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_19_R1_2004_01-02_ORIG_MID--AUDIO_19_R1_2004_03_Track03_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_11_R1_2004_03-04_ORIG_MID--AUDIO_11_R1_2004_04_Track04_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_01_R1_2004_04-05_ORIG_MID--AUDIO_01_R1_2004_05_Track05_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_16_R1_2004_01-08_ORIG_MID--AUDIO_16_R1_2004_06_Track06_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_15_R1_2004_01-02_ORIG_MID--AUDIO_15_R1_2004_01_Track01_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_22_R2_2004_01_ORIG_MID--AUDIO_22_R2_2004_03_Track03_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_15_R1_2004_01-02_ORIG_MID--AUDIO_15_R1_2004_02_Track02_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_17_R1_2004_01-03_ORIG_MID--AUDIO_17_R1_2004_06_Track06_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_01_R1_2004_04-05_ORIG_MID--AUDIO_01_R1_2004_06_Track06_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_09_R1_2004_05_ORIG_MID--AUDIO_09_R1_2004_07_Track07_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_21_R1_2004_02_ORIG_MID--AUDIO_21_R1_2004_02_Track02_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_14_R1_2004_04_ORIG_MID--AUDIO_14_R1_2004_05_Track05_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_06_R1_2004_02-03_ORIG_MID--AUDIO_06_R1_2004_05_Track05_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_14_R1_2004_01-03_ORIG_MID--AUDIO_14_R1_2004_03_Track03_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_20_R2_2004_01_ORIG_MID--AUDIO_20_R1_2004_03_Track03_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_03_R1_2004_01-02_ORIG_MID--AUDIO_03_R1_2004_02_Track02_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_14_R1_2004_04_ORIG_MID--AUDIO_14_R1_2004_06_Track06_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_18_R1_2004_01-02_ORIG_MID--AUDIO_18_R1_2004_05_Track05_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_04_R1_2004_03-05_ORIG_MID--AUDIO_04_R1_2004_05_Track05_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_09_R1_2004_01-02_ORIG_MID--AUDIO_09_R1_2004_03_Track03_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_13_01_2004_01-05_ORIG_MID--AUDIO_13_R1_2004_02_Track02_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_03_R1_2004_01-02_ORIG_MID--AUDIO_03_R1_2004_01_Track01_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_22_R1_2004_01-04_ORIG_MID--AUDIO_22_R1_2004_05_Track05_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_14_R2_2004_01_ORIG_MID--AUDIO_14_R2_2004_02_Track02_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_17_R1_2004_03-06_ORIG_MID--AUDIO_20_R2_2004_12_Track12_wav--2.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_05_R1_2004_01_ORIG_MID--AUDIO_05_R1_2004_02_Track02_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_17_R2_2004_01_ORIG_MID--AUDIO_17_R2_2004_01_Track01_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_04_R1_2004_03-05_ORIG_MID--AUDIO_04_R1_2004_06_Track06_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_17_R2_2004_01_ORIG_MID--AUDIO_17_R2_2004_04_Track04_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_16_R1_2004_01-08_ORIG_MID--AUDIO_16_R1_2004_05_Track05_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_20_R2_2004_01_ORIG_MID--AUDIO_20_R1_2004_02_Track02_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_17_R1_2004_04_ORIG_MID--AUDIO_17_R1_2004_11_Track11_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_14_R2_2004_01_ORIG_MID--AUDIO_14_R2_2004_03_Track03_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_17_R1_2004_01-03_ORIG_MID--AUDIO_17_R1_2004_02_Track02_wav--1.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_08_R1_2004_04-06_ORIG_MID--AUDIO_08_R1_2004_04_Track04_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_11_R1_2004_03-04_ORIG_MID--AUDIO_11_R1_2004_03_Track03_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_13_01_2004_01-05_ORIG_MID--AUDIO_13_R1_2004_05_Track05_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_12_01_2004_01-05_ORIG_MID--AUDIO_12_R1_2004_10_Track10_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_XP_22_R2_2004_01_ORIG_MID--AUDIO_22_R2_2004_02_Track02_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2004/MIDI-Unprocessed_SMF_12_01_2004_01-05_ORIG_MID--AUDIO_12_R1_2004_08_Track08_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_22_R2_2011_MID--AUDIO_R2-D5_11_Track11_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_02_R1_2011_MID--AUDIO_R1-D1_09_Track09_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_17_R1_2011_MID--AUDIO_R1-D7_03_Track03_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_21_R1_2011_MID--AUDIO_R1-D8_09_Track09_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_04_R3_2011_MID--AUDIO_R3-D2_03_Track03_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_08_R1_2011_MID--AUDIO_R1-D3_10_Track10_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_12_R3_2011_MID--AUDIO_R3-D4_08_Track08_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_25_R2_2011_MID--AUDIO_R2-D6_07_Track07_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_22_R3_2011_MID--AUDIO_R3-D7_08_Track08_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_06_R1_2011_MID--AUDIO_R1-D2_16_Track16_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_03_R1_2011_MID--AUDIO_R1-D1_17_Track17_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_03_R2_2011_MID--AUDIO_R2-D1_07_Track07_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_25_R3_2011_MID--AUDIO_R3-D9_02_Track02_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_12_R2_2011_MID--AUDIO_R2-D4_02_Track02_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_04_R2_2011_MID--AUDIO_R2-D2_03_Track03_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_16_R1_2011_MID--AUDIO_R1-D6_12_Track12_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_01_R1_2011_MID--AUDIO_R1-D1_04_Track04_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_17_R3_2011_MID--AUDIO_R3-D6_03_Track03_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_22_R1_2011_MID--AUDIO_R1-D8_12_Track12_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_13_R1_2011_MID--AUDIO_R1-D5_04_Track04_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_17_R3_2011_MID--AUDIO_R3-D6_05_Track05_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_22_R1_2011_MID--AUDIO_R1-D8_11_Track11_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_04_R1_2011_MID--AUDIO_R1-D2_03_Track03_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_21_R1_2011_MID--AUDIO_R1-D8_07_Track07_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_17_R3_2011_MID--AUDIO_R3-D6_04_Track04_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_09_R2_2011_MID--AUDIO_R2-D3_03_Track03_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_06_R3_2011_MID--AUDIO_R3-D3_02_Track02_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_01_R1_2011_MID--AUDIO_R1-D1_06_Track06_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_09_R1_2011_MID--AUDIO_R1-D3_14_Track14_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_16_R1_2011_MID--AUDIO_R1-D6_15_Track15_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_22_R3_2011_MID--AUDIO_R3-D7_07_Track07_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_12_R3_2011_MID--AUDIO_R3-D4_04_Track04_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_07_R1_2011_MID--AUDIO_R1-D3_03_Track03_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_19_R1_2011_MID--AUDIO_R1-D7_15_Track15_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_14_R1_2011_MID--AUDIO_R1-D6_03_Track03_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_19_R1_2011_MID--AUDIO_R1-D7_14_Track14_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_03_R2_2011_MID--AUDIO_R2-D1_06_Track06_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_15_R1_2011_MID--AUDIO_R1-D6_10_Track10_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_11_R1_2011_MID--AUDIO_R1-D4_07_Track07_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_12_R3_2011_MID--AUDIO_R3-D4_07_Track07_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_15_R1_2011_MID--AUDIO_R1-D6_08_Track08_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_11_R1_2011_MID--AUDIO_R1-D4_09_Track09_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_03_R3_2011_MID--AUDIO_R3-D1_05_Track05_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_10_R2_2011_MID--AUDIO_R2-D3_11_Track11_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_06_R1_2011_MID--AUDIO_R1-D2_15_Track15_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_13_R1_2011_MID--AUDIO_R1-D5_03_Track03_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_23_R2_2011_MID--AUDIO_R2-D6_03_Track03_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_06_R2_2011_MID--AUDIO_R2-D2_06_Track06_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_03_R3_2011_MID--AUDIO_R3-D1_04_Track04_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_08_R1_2011_MID--AUDIO_R1-D3_08_Track08_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_09_R2_2011_MID--AUDIO_R2-D3_04_Track04_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_17_R2_2011_MID--AUDIO_R2-D5_04_Track04_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_17_R2_2011_MID--AUDIO_R2-D5_03_Track03_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_02_R1_2011_MID--AUDIO_R1-D1_08_Track08_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_17_R3_2011_MID--AUDIO_R3-D6_06_Track06_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_03_R2_2011_MID--AUDIO_R2-D1_08_Track08_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_04_R1_2011_MID--AUDIO_R1-D2_06_Track06_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_10_R1_2011_MID--AUDIO_R1-D4_05_Track05_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_03_R3_2011_MID--AUDIO_R3-D1_07_Track07_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_16_R3_2011_MID--AUDIO_R3-D5_02_Track02_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_25_R3_2011_MID--AUDIO_R3-D9_05_Track05_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_08_R1_2011_MID--AUDIO_R1-D3_09_Track09_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_02_R2_2011_MID--AUDIO_R2-D1_02_Track02_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_07_R1_2011_MID--AUDIO_R1-D3_04_Track04_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_21_R1_2011_MID--AUDIO_R1-D8_08_Track08_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_11_R1_2011_MID--AUDIO_R1-D4_08_Track08_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_03_R1_2011_MID--AUDIO_R1-D1_15_Track15_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_04_R3_2011_MID--AUDIO_R3-D2_06_Track06_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_12_R1_2011_MID--AUDIO_R1-D4_15_Track15_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_12_R3_2011_MID--AUDIO_R3-D4_02_Track02_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_24_R1_2011_MID--AUDIO_R1-D9_10_Track10_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_05_R1_2011_MID--AUDIO_R1-D2_08_Track08_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_23_R1_2011_MID--AUDIO_R1-D9_02_Track02_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_03_R1_2011_MID--AUDIO_R1-D1_19_Track19_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_03_R3_2011_MID--AUDIO_R3-D1_02_Track02_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_20_R1_2011_MID--AUDIO_R1-D8_02_Track02_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_02_R2_2011_MID--AUDIO_R2-D1_03_Track03_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_05_R1_2011_MID--AUDIO_R1-D2_12_Track12_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_07_R1_2011_MID--AUDIO_R1-D3_05_Track05_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_19_R1_2011_MID--AUDIO_R1-D7_12_Track12_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_24_R1_2011_MID--AUDIO_R1-D9_11_Track11_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_22_R2_2011_MID--AUDIO_R2-D5_10_Track10_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_17_R3_2011_MID--AUDIO_R3-D6_02_Track02_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_19_R1_2011_MID--AUDIO_R1-D7_13_Track13_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_25_R3_2011_MID--AUDIO_R3-D9_06_Track06_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_17_R3_2011_MID--AUDIO_R3-D6_08_Track08_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_10_R1_2011_MID--AUDIO_R1-D4_04_Track04_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_23_R3_2011_MID--AUDIO_R3-D8_04_Track04_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_22_R2_2011_MID--AUDIO_R2-D5_08_Track08_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_25_R1_2011_MID--AUDIO_R1-D9_14_Track14_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_03_R1_2011_MID--AUDIO_R1-D1_16_Track16_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_11_R1_2011_MID--AUDIO_R1-D4_11_Track11_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_23_R1_2011_MID--AUDIO_R1-D9_03_Track03_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_03_R3_2011_MID--AUDIO_R3-D1_06_Track06_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_12_R2_2011_MID--AUDIO_R2-D4_05_Track05_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_23_R2_2011_MID--AUDIO_R2-D6_04_Track04_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_04_R3_2011_MID--AUDIO_R3-D2_05_Track05_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_24_R1_2011_MID--AUDIO_R1-D9_08_Track08_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_22_R1_2011_MID--AUDIO_R1-D8_13_Track13_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_04_R3_2011_MID--AUDIO_R3-D2_04_Track04_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_06_R3_2011_MID--AUDIO_R3-D3_06_Track06_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_16_R1_2011_MID--AUDIO_R1-D6_13_Track13_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_01_R1_2011_MID--AUDIO_R1-D1_02_Track02_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_18_R1_2011_MID--AUDIO_R1-D7_09_Track09_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_04_R1_2011_MID--AUDIO_R1-D2_04_Track04_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_03_R1_2011_MID--AUDIO_R1-D1_18_Track18_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_23_R1_2011_MID--AUDIO_R1-D9_05_Track05_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_17_R1_2011_MID--AUDIO_R1-D7_04_Track04_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_20_R1_2011_MID--AUDIO_R1-D8_04_Track04_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_17_R2_2011_MID--AUDIO_R2-D5_06_Track06_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_17_R1_2011_MID--AUDIO_R1-D7_05_Track05_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_22_R3_2011_MID--AUDIO_R3-D7_03_Track03_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_16_R1_2011_MID--AUDIO_R1-D6_14_Track14_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_25_R2_2011_MID--AUDIO_R2-D6_08_Track08_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_06_R1_2011_MID--AUDIO_R1-D2_14_Track14_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_04_R2_2011_MID--AUDIO_R2-D2_02_Track02_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_12_R3_2011_MID--AUDIO_R3-D4_09_Track09_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_09_R1_2011_MID--AUDIO_R1-D3_15_Track15_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_06_R3_2011_MID--AUDIO_R3-D3_05_Track05_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_12_R1_2011_MID--AUDIO_R1-D4_13_Track13_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_18_R1_2011_MID--AUDIO_R1-D7_08_Track08_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_06_R2_2011_MID--AUDIO_R2-D2_07_Track07_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_21_R1_2011_MID--AUDIO_R1-D8_10_Track10_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_11_R1_2011_MID--AUDIO_R1-D4_10_Track10_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_09_R1_2011_MID--AUDIO_R1-D3_13_Track13_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_07_R1_2011_MID--AUDIO_R1-D3_02_Track02_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_13_R1_2011_MID--AUDIO_R1-D5_02_Track02_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_01_R1_2011_MID--AUDIO_R1-D1_05_Track05_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_01_R1_2011_MID--AUDIO_R1-D1_03_Track03_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_16_R2_2011_MID--AUDIO_R2-D4_08_Track08_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_05_R1_2011_MID--AUDIO_R1-D2_09_Track09_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_18_R1_2011_MID--AUDIO_R1-D7_07_Track07_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_23_R3_2011_MID--AUDIO_R3-D8_03_Track03_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_16_R2_2011_MID--AUDIO_R2-D4_09_Track09_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_14_R1_2011_MID--AUDIO_R1-D6_04_Track04_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_12_R3_2011_MID--AUDIO_R3-D4_03_Track03_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_20_R1_2011_MID--AUDIO_R1-D8_03_Track03_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_23_R1_2011_MID--AUDIO_R1-D9_04_Track04_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_24_R1_2011_MID--AUDIO_R1-D9_09_Track09_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_23_R3_2011_MID--AUDIO_R3-D8_05_Track05_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_08_R1_2011_MID--AUDIO_R1-D3_07_Track07_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_18_R1_2011_MID--AUDIO_R1-D7_10_Track10_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_25_R1_2011_MID--AUDIO_R1-D9_15_Track15_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_17_R3_2011_MID--AUDIO_R3-D6_07_Track07_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_10_R2_2011_MID--AUDIO_R2-D3_10_Track10_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_22_R3_2011_MID--AUDIO_R3-D7_09_Track09_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_15_R1_2011_MID--AUDIO_R1-D6_09_Track09_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_12_R2_2011_MID--AUDIO_R2-D4_03_Track03_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_25_R3_2011_MID--AUDIO_R3-D9_03_Track03_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_14_R1_2011_MID--AUDIO_R1-D6_02_Track02_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_04_R1_2011_MID--AUDIO_R1-D2_02_Track02_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_25_R3_2011_MID--AUDIO_R3-D9_04_Track04_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_05_R1_2011_MID--AUDIO_R1-D2_10_Track10_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_12_R1_2011_MID--AUDIO_R1-D4_14_Track14_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_15_R1_2011_MID--AUDIO_R1-D6_07_Track07_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_05_R1_2011_MID--AUDIO_R1-D2_11_Track11_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_09_R1_2011_MID--AUDIO_R1-D3_12_Track12_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_17_R1_2011_MID--AUDIO_R1-D7_02_Track02_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_12_R2_2011_MID--AUDIO_R2-D4_04_Track04_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_02_R1_2011_MID--AUDIO_R1-D1_10_Track10_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_03_R3_2011_MID--AUDIO_R3-D1_03_Track03_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_10_R1_2011_MID--AUDIO_R1-D4_02_Track02_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2011/MIDI-Unprocessed_06_R1_2011_MID--AUDIO_R1-D2_17_Track17_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2006/MIDI-Unprocessed_07_R1_2006_01-04_ORIG_MID--AUDIO_07_R1_2006_01_Track01_wav.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2006/MIDI-Unprocessed_16_R1_2006_01-04_ORIG_MID--AUDIO_16_R1_2006_02_Track02_wav.midi
# ...
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_12_R1_2009_03-05_ORIG_MID--AUDIO_12_R1_2009_12_R1_2009_05_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_12_R2_2009_01_ORIG_MID--AUDIO_12_R2_2009_12_R2_2009_02_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_09_R1_2009_01-04_ORIG_MID--AUDIO_09_R1_2009_09_R1_2009_03_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_14_R1_2009_01-05_ORIG_MID--AUDIO_14_R1_2009_14_R1_2009_03_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_13_R1_2009_01-03_ORIG_MID--AUDIO_13_R1_2009_13_R1_2009_01_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_18_R1_2009_01-03_ORIG_MID--AUDIO_18_R1_2009_18_R1_2009_02_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_17_R1_2009_04_ORIG_MID--AUDIO_17_R1_2009_17_R1_2009_04_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_10_R2_2009_01_ORIG_MID--AUDIO_10_R2_2009_10_R2_2009_03_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_05_R1_2009_03-05_ORIG_MID--AUDIO_05_R1_2009_05_R1_2009_03_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_17_R2_2009_01_ORIG_MID--AUDIO_17_R2_2009_17_R2_2009_01_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_17_R1_2009_01-03_ORIG_MID--AUDIO_17_R1_2009_17_R1_2009_01_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_16_R2_2009_01_ORIG_MID--AUDIO_16_R2_2009_16_R2_2009_02_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_10_R1_2009_03-05_ORIG_MID--AUDIO_10_R1_2009_10_R1_2009_03_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_12_R2_2009_01_ORIG_MID--AUDIO_12_R2_2009_12_R2_2009_01_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_07_R2_2009_01_ORIG_MID--AUDIO_07_R2_2009_07_R2_2009_03_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_14_R1_2009_06-08_ORIG_MID--AUDIO_14_R1_2009_14_R1_2009_08_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_11_R1_2009_06-09_ORIG_MID--AUDIO_11_R1_2009_11_R1_2009_07_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_08_R1_2009_05-06_ORIG_MID--AUDIO_08_R1_2009_08_R1_2009_06_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_15_R1_2009_03-06_ORIG_MID--AUDIO_15_R1_2009_15_R1_2009_03_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_19_R2_2009_01_ORIG_MID--AUDIO_19_R2_2009_19_R2_2009_04_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_15_R1_2009_03-06_ORIG_MID--AUDIO_15_R1_2009_15_R1_2009_06_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_09_R1_2009_01-04_ORIG_MID--AUDIO_09_R1_2009_09_R1_2009_02_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_03_R1_2009_03-08_ORIG_MID--AUDIO_03_R1_2009_03_R1_2009_03_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_11_R1_2009_01-05_ORIG_MID--AUDIO_11_R1_2009_11_R1_2009_04_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_09_R2_2009_01_ORIG_MID--AUDIO_09_R2_2009_09_R2_2009_04_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_15_R1_2009_01-02_ORIG_MID--AUDIO_15_R1_2009_15_R1_2009_01_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_04_R1_2009_04-06_ORIG_MID--AUDIO_04_R1_2009_04_R1_2009_04_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_11_R1_2009_06-09_ORIG_MID--AUDIO_11_R1_2009_11_R1_2009_08_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_15_R1_2009_03-06_ORIG_MID--AUDIO_15_R1_2009_15_R1_2009_05_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_15_R1_2009_01-02_ORIG_MID--AUDIO_15_R1_2009_15_R1_2009_02_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_08_R2_2009_01_ORIG_MID--AUDIO_08_R2_2009_08_R2_2009_04_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_12_R2_2009_01_ORIG_MID--AUDIO_12_R2_2009_12_R2_2009_04_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_06_R1_2009_03-07_ORIG_MID--AUDIO_06_R1_2009_06_R1_2009_07_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_03_R1_2009_03-08_ORIG_MID--AUDIO_03_R1_2009_03_R1_2009_08_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_13_R1_2009_01-03_ORIG_MID--AUDIO_13_R1_2009_13_R1_2009_03_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_21_R2_2009_01_ORIG_MID--AUDIO_21_R2_2009_21_R2_2009_04_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_08_R2_2009_01_ORIG_MID--AUDIO_08_R2_2009_08_R2_2009_02_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_12_R2_2009_01_ORIG_MID--AUDIO_12_R2_2009_12_R2_2009_03_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_04_R1_2009_04-06_ORIG_MID--AUDIO_04_R1_2009_04_R1_2009_05_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_06_R1_2009_01-02_ORIG_MID--AUDIO_06_R1_2009_06_R1_2009_02_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_20_R1_2009_01-05_ORIG_MID--AUDIO_20_R1_2009_20_R1_2009_02_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_17_R2_2009_01_ORIG_MID--AUDIO_17_R2_2009_17_R2_2009_02_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_07_R1_2009_04-05_ORIG_MID--AUDIO_07_R1_2009_07_R1_2009_05_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_11_R1_2009_06-09_ORIG_MID--AUDIO_11_R1_2009_11_R1_2009_09_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_08_R2_2009_01_ORIG_MID--AUDIO_08_R2_2009_08_R2_2009_03_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_05_R1_2009_01-02_ORIG_MID--AUDIO_05_R1_2009_05_R1_2009_02_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_07_R2_2009_01_ORIG_MID--AUDIO_07_R2_2009_07_R2_2009_02_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_01_R1_2009_01-04_ORIG_MID--AUDIO_01_R1_2009_01_R1_2009_04_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_18_R1_2009_01-03_ORIG_MID--AUDIO_18_R1_2009_18_R1_2009_01_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_02_R1_2009_03-06_ORIG_MID--AUDIO_02_R1_2009_02_R1_2009_04_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_09_R1_2009_01-04_ORIG_MID--AUDIO_09_R1_2009_09_R1_2009_01_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_12_R1_2009_01-02_ORIG_MID--AUDIO_12_R1_2009_12_R1_2009_01_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_02_R1_2009_01-02_ORIG_MID--AUDIO_02_R1_2009_02_R1_2009_01_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_12_R1_2009_03-05_ORIG_MID--AUDIO_12_R1_2009_12_R1_2009_03_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_07_R1_2009_01-03_ORIG_MID--AUDIO_07_R1_2009_07_R1_2009_02_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_07_R2_2009_01_ORIG_MID--AUDIO_07_R2_2009_07_R2_2009_04_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_11_R1_2009_06-09_ORIG_MID--AUDIO_11_R1_2009_11_R1_2009_06_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_02_R1_2009_03-06_ORIG_MID--AUDIO_02_R1_2009_02_R1_2009_05_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_08_R1_2009_01-04_ORIG_MID--AUDIO_08_R1_2009_08_R1_2009_03_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_01_R1_2009_01-04_ORIG_MID--AUDIO_01_R1_2009_01_R1_2009_02_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_08_R2_2009_01_ORIG_MID--AUDIO_08_R2_2009_08_R2_2009_01_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_09_R1_2009_01-04_ORIG_MID--AUDIO_09_R1_2009_09_R1_2009_04_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_10_R1_2009_01-02_ORIG_MID--AUDIO_10_R1_2009_10_R1_2009_01_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_09_R2_2009_01_ORIG_MID--AUDIO_09_R2_2009_09_R2_2009_02_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_20_R1_2009_01-05_ORIG_MID--AUDIO_20_R1_2009_20_R1_2009_01_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_17_R2_2009_01_ORIG_MID--AUDIO_17_R2_2009_17_R2_2009_03_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_21_R2_2009_01_ORIG_MID--AUDIO_21_R2_2009_21_R2_2009_02_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_03_R1_2009_03-08_ORIG_MID--AUDIO_03_R1_2009_03_R1_2009_07_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_16_R2_2009_01_ORIG_MID--AUDIO_16_R2_2009_16_R2_2009_01_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_21_R1_2009_04_ORIG_MID--AUDIO_21_R1_2009_21_R1_2009_04_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_05_R1_2009_01-02_ORIG_MID--AUDIO_05_R1_2009_05_R1_2009_01_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_10_R2_2009_01_ORIG_MID--AUDIO_10_R2_2009_10_R2_2009_02_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_02_R1_2009_03-06_ORIG_MID--AUDIO_02_R1_2009_02_R1_2009_03_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_03_R1_2009_01-02_ORIG_MID--AUDIO_03_R1_2009_03_R1_2009_02_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_21_R2_2009_01_ORIG_MID--AUDIO_21_R2_2009_21_R2_2009_01_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_19_R2_2009_01_ORIG_MID--AUDIO_19_R2_2009_19_R2_2009_03_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_07_R1_2009_01-03_ORIG_MID--AUDIO_07_R1_2009_07_R1_2009_03_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_11_R1_2009_01-05_ORIG_MID--AUDIO_11_R1_2009_11_R1_2009_02_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_14_R1_2009_01-05_ORIG_MID--AUDIO_14_R1_2009_14_R1_2009_04_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_11_R1_2009_01-05_ORIG_MID--AUDIO_11_R1_2009_11_R1_2009_01_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_14_R1_2009_01-05_ORIG_MID--AUDIO_14_R1_2009_14_R1_2009_02_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_14_R1_2009_01-05_ORIG_MID--AUDIO_14_R1_2009_14_R1_2009_05_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_11_R1_2009_01-05_ORIG_MID--AUDIO_11_R1_2009_11_R1_2009_03_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_16_R2_2009_01_ORIG_MID--AUDIO_16_R2_2009_16_R2_2009_04_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_10_R2_2009_01_ORIG_MID--AUDIO_10_R2_2009_10_R2_2009_01_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_19_R1_2009_03-04_ORIG_MID--AUDIO_19_R1_2009_19_R1_2009_04_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_09_R1_2009_05-06_ORIG_MID--AUDIO_09_R1_2009_09_R1_2009_05_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_06_R1_2009_03-07_ORIG_MID--AUDIO_06_R1_2009_06_R1_2009_06_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_08_R1_2009_01-04_ORIG_MID--AUDIO_08_R1_2009_08_R1_2009_02_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_08_R1_2009_01-04_ORIG_MID--AUDIO_08_R1_2009_08_R1_2009_04_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_09_R2_2009_01_ORIG_MID--AUDIO_09_R2_2009_09_R2_2009_01_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_07_R1_2009_04-05_ORIG_MID--AUDIO_07_R1_2009_07_R1_2009_04_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/2009/MIDI-Unprocessed_09_R2_2009_01_ORIG_MID--AUDIO_09_R2_2009_09_R2_2009_03_WAV.midi
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/maestro-v3.0.0.csv
#   inflating: /content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0/README

# %%
# Load and process MIDI files
dataset_addr = "/content/Tiny-Music-Transformer/maestro_dataset_v3/maestro-v3.0.0"
filez = [os.path.join(dirpath, file) for dirpath, _, filenames in os.walk(dataset_addr) for file in filenames]

# %%
len(filez)
# Out:
# 1280

# %%
# %cd /content/

if not os.path.exists('/content/INTS'):
    os.makedirs('/content/INTS')

import random
from joblib import Parallel, delayed, parallel_config

melody_chords_f = []

print('Processing MIDI files. Please wait...')
print('=' * 70)

for i in tqdm.tqdm(range(0, len(filez), 16)):

  with parallel_config(backend='threading', n_jobs=16, verbose = 0):

    output = Parallel()(delayed(TMIDIX_MIDI_Processor)(f) for f in filez[i:i+16])

    for o in output:

        if o is not None:
            melody_chords_f.append(o)
# Out:
# /content
# Processing MIDI files. Please wait...
# ======================================================================
#   0%|          | 0/80 [00:00<?, ?it/s]
# Error!
# Exception list index out of range
# Error!
# Exception list index out of rangeError!
# Exception
# Error!
# Exception list index out of range
#  list index out of range
# midi2opus: midi starts with b'Plea' instead of 'MThd'
# midi2opus: midi starts with b'Attr' instead of 'MThd'
# midi2opus: midi starts with b'{"ca' instead of 'MThd'
# midi2opus: midi starts with b'cano' instead of 'MThd'
# 100%|██████████| 80/80 [15:57<00:00, 11.96s/it]

# %%
# @title Convert processed MIDIs to INTs
SEQ_LEN = 8192
PAD_IDX = 643

train_data = []

for m in tqdm.tqdm(melody_chords_f):

    if m[0][2] == 0:
        cha = 0
    if m[0][2] == 3:
        cha = 1

    dat = [642, 512+cha, m[0][3]+514, 0]

    for mm in m:

        if mm[2] == 0:
            cha = 0
        if mm[2] == 3:
            cha = 1

        if mm[0] != 0:
           dat.extend([mm[0], mm[1]+128, ((cha * 128) + mm[3])+256])
        else:
           dat.extend([mm[1]+128, ((cha * 128) + mm[3])+256])

    dat = dat[:SEQ_LEN+1]
    dat += [PAD_IDX] * (SEQ_LEN+1 - len(dat))

    train_data.append(dat)

random.shuffle(train_data)

print('Done!')
# Out:
# 100%|██████████| 1276/1276 [00:04<00:00, 282.07it/s]
# Done!

# %%
# @title Save and Load INTs
TMIDIX.Tegridy_Any_Pickle_File_Writer(train_data, '/content/Training_INTs_maestro')

train_data = TMIDIX.Tegridy_Any_Pickle_File_Reader('/content/Training_INTs_maestro')
print('Done!')
# Out:
# Tegridy Pickle File Writer
# Creating new Dataset file...
# Dataset was saved as: /content/Training_INTs_maestro.pickle
# Task complete. Enjoy! :)
# Tegridy Pickle File Loader
# Loading the pickle file. Please wait...
# Done!

# %%
#@title Load Tiny Music Transformer Pre-Trained Model

select_model_to_load = "139M-32L-Very-Fast-Tiny"

model_precision = "bfloat16"

plot_tokens_embeddings = "None"

full_path_to_models_dir = "/content/Tiny-Music-Transformer/Model/"

print('Loading Tiny Music Transformer Training Data...')
print('Please wait...')

training_data_file = 'Tiny_Music_Transformer_Train_Data_Mono_Melodies_Piano_Violin_MIDI_Dataset.pickle'

if os.path.isfile(full_path_to_models_dir+training_data_file):
  print('Training data already exists...')

else:
  hf_hub_download(repo_id='asigalov61/Tiny-Music-Transformer',
                  filename=training_data_file,
                  local_dir='/content/Tiny-Music-Transformer/Model',
                  local_dir_use_symlinks=False)

train_data = TMIDIX.Tegridy_Any_Pickle_File_Reader('/content/Tiny-Music-Transformer/Model/Tiny_Music_Transformer_Train_Data_Mono_Melodies_Piano_Violin_MIDI_Dataset')
print('Done!')
print('Loading Tiny Music Transformer', select_model_to_load,'Pre-Trained Model...')

if select_model_to_load == '139M-32L-Very-Fast-Tiny':

  model_checkpoint_file_name = 'Tiny_Music_Transformer_Tiny_Trained_Model_10737_steps_0.4039_loss_0.8729_acc.pth'
  model_path = full_path_to_models_dir+model_checkpoint_file_name
  if os.path.isfile(model_path):
    print('Model already exists...')

  else:
    hf_hub_download(repo_id='asigalov61/Tiny-Music-Transformer',
                    filename=model_checkpoint_file_name,
                    local_dir='/content/Tiny-Music-Transformer/Model',
                    local_dir_use_symlinks=False)



print('=' * 70)
print('Instantiating model...')

torch.backends.cuda.matmul.allow_tf32 = True # allow tf32 on matmul
torch.backends.cudnn.allow_tf32 = True # allow tf32 on cudnn
device_type = 'cuda'

if model_precision == 'bfloat16' and torch.cuda.is_bf16_supported():
  dtype = 'bfloat16'
else:
  dtype = 'float16'

if model_precision == 'float16':
  dtype = 'float16'

ptdtype = {'float32': torch.float32, 'bfloat16': torch.bfloat16, 'float16': torch.float16}[dtype]
ctx = torch.amp.autocast(device_type=device_type, dtype=ptdtype)

SEQ_LEN = 8192

model = TransformerWrapper(
    num_tokens = 644,
    max_seq_len = SEQ_LEN,
    attn_layers = Decoder(dim = 512, depth = 32, heads = 16, attn_flash = True)
)

model = AutoregressiveWrapper(model, ignore_index=643)

model.cuda()
model.load_state_dict(torch.load(model_path))

model.eval()

print('Done!')

print('Model will use', dtype, 'precision...')

# Model stats
print('Model summary...')
summary(model)
# Out:
# Loading Tiny Music Transformer Training Data...
# Please wait...
# Training data already exists...
# Tegridy Pickle File Loader
# Loading the pickle file. Please wait...
# Done!
# Loading Tiny Music Transformer 139M-32L-Very-Fast-Tiny Pre-Trained Model...
# Model already exists...
# ======================================================================
# Instantiating model...
# Non-A100 GPU detected, using math or mem efficient attention if input tensor is on cuda
# Done!
# Model will use float16 precision...
# Model summary...
# ======================================================================
# Layer (type:depth-idx)                        Param #
# ======================================================================
# ├─TransformerWrapper: 1-1                     --
# |    └─TokenEmbedding: 2-1                    --
# |    |    └─Embedding: 3-1                    329,728
# |    └─AbsolutePositionalEmbedding: 2-2       --
# |    |    └─Embedding: 3-2                    4,194,304
# |    └─Identity: 2-3                          --
# |    └─Dropout: 2-4                           --
# |    └─Identity: 2-5                          --
# |    └─Decoder: 2-6                           --
# |    |    └─ModuleList: 3-3                   134,365,184
# |    |    └─LayerNorm: 3-4                    1,024
# |    └─Linear: 2-7                            330,372
# ======================================================================
# Total params: 139,220,612
# Trainable params: 139,220,612
# Non-trainable params: 0
# ======================================================================
# ======================================================================
# Layer (type:depth-idx)                        Param #
# ======================================================================
# ├─TransformerWrapper: 1-1                     --
# |    └─TokenEmbedding: 2-1                    --
# |    |    └─Embedding: 3-1                    329,728
# |    └─AbsolutePositionalEmbedding: 2-2       --
# |    |    └─Embedding: 3-2                    4,194,304
# |    └─Identity: 2-3                          --
# |    └─Dropout: 2-4                           --
# |    └─Identity: 2-5                          --
# |    └─Decoder: 2-6                           --
# |    |    └─ModuleList: 3-3                   134,365,184
# |    |    └─LayerNorm: 3-4                    1,024
# |    └─Linear: 2-7                            330,372
# ======================================================================
# Total params: 139,220,612
# Trainable params: 139,220,612
# Non-trainable params: 0
# ======================================================================

# %%
#@title Model Parameters
SEQ_LEN = 8192 # Models seq len
PAD_IDX = 643 # Models pad index

BATCH_SIZE = 4
NUM_EPOCHS = 25
GRADIENT_ACCUMULATE_EVERY = 4

LEARNING_RATE = 2e-4

VALIDATE_EVERY  = 10
SAVE_EVERY = 25
GENERATE_EVERY  = 100
PRINT_STATS_EVERY = 20

GENERATE_LENGTH = 32

# helpers

def cycle(loader):
    while True:
        for data in loader:
            yield data

# %%
class MusicDataset(Dataset):
    def __init__(self, data, seq_len):
        super().__init__()
        self.data = data
        self.seq_len = seq_len

    def __getitem__(self, index):

        full_seq = torch.Tensor(self.data[index][:self.seq_len+1]).long()

        return full_seq.cuda()

    def __len__(self):
        return (len(self.data) // BATCH_SIZE) * BATCH_SIZE

# %%
#@title precision/optimizer/scaler

dtype = torch.float16
ctx = torch.amp.autocast(device_type='cuda', dtype=dtype)
optim = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)
scaler = torch.cuda.amp.GradScaler(enabled=True)

# %%
import gc
torch.cuda.empty_cache()
gc.collect()
# Out:
# 53

# %%
train_losses = []
val_losses = []

train_accs = []
val_accs = []

nsteps = 0

for ep in range(NUM_EPOCHS):

  print('Epoch #', ep)

  random.shuffle(train_data)

  train_dataset = MusicDataset(train_data, SEQ_LEN)
  val_dataset   = MusicDataset(train_data, SEQ_LEN)

  train_loader  = cycle(DataLoader(train_dataset, batch_size = BATCH_SIZE))
  val_loader    = cycle(DataLoader(val_dataset, batch_size = BATCH_SIZE))

  NUM_BATCHES = len(train_data) // BATCH_SIZE // GRADIENT_ACCUMULATE_EVERY

  for i in tqdm.tqdm(range(NUM_BATCHES), mininterval=10., desc='Training'):

      model.train()

      for __ in range(GRADIENT_ACCUMULATE_EVERY):
          with ctx:
              loss, acc = model(next(train_loader))
          loss = loss / GRADIENT_ACCUMULATE_EVERY
          scaler.scale(loss).backward(torch.ones(loss.shape).cuda())

      if i % PRINT_STATS_EVERY == 0:
          print(f'Training loss: {loss.mean().item() * GRADIENT_ACCUMULATE_EVERY}')
          print(f'Training acc: {acc.mean().item()}')

      train_losses.append(loss.mean().item() * GRADIENT_ACCUMULATE_EVERY)
      train_accs.append(acc.mean().item())

      scaler.unscale_(optim)
      torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
      scaler.step(optim)
      scaler.update()
      optim.zero_grad(set_to_none=True)

      nsteps += 1

      if i % VALIDATE_EVERY == 0:
        model.eval()
        with torch.no_grad():
          with ctx:
            val_loss, val_acc = model(next(val_loader))

            print(f'Validation loss: {val_loss.mean().item()}')
            print(f'Validation acc: {val_acc.mean().item()}')

            val_losses.append(val_loss.mean().item())
            val_accs.append(val_acc.mean().item())

            print('Plotting training loss graph...')

            tr_loss_list = train_losses
            plt.plot([i for i in range(len(tr_loss_list))] ,tr_loss_list, 'b')
            plt.show()
            plt.close()
            print('Done!')

            print('Plotting validation loss graph...')
            tr_loss_list = val_losses
            plt.plot([i for i in range(len(tr_loss_list))] ,tr_loss_list, 'b')
            plt.show()
            plt.close()
            print('Done!')

      if i % GENERATE_EVERY == 0:
        model.eval()

        inp = random.choice(val_dataset)[:-1]

        print(inp)

        with ctx:

            sample = model.generate(inp[None, ...], GENERATE_LENGTH)

        print(sample)

      if i % SAVE_EVERY == 0:

          print('Saving model progress. Please wait...')
          print('model_checkpoint_' + str(nsteps) + '_steps_' + str(round(float(train_losses[-1]), 4)) + '_loss_' + str(round(float(train_accs[-1]), 4)) + '_acc.pth')

          fname = '/content/model_checkpoint_' + str(nsteps) + '_steps_' + str(round(float(train_losses[-1]), 4)) + '_loss_' + str(round(float(train_accs[-1]), 4)) + '_acc.pth'

          torch.save(model.state_dict(), fname)

          data = [train_losses, train_accs, val_losses, val_accs]

          TMIDIX.Tegridy_Any_Pickle_File_Writer(data, '/content/losses_accs')

          print('Done!')


print('Saving model progress. Please wait...')
print('model_checkpoint_' + str(nsteps) + '_steps_' + str(round(float(train_losses[-1]), 4)) + '_loss_' + str(round(float(train_accs[-1]), 4)) + '_acc.pth')

fname = '/content/model_checkpoint_' + str(nsteps) + '_steps_' + str(round(float(train_losses[-1]), 4)) + '_loss_' + str(round(float(train_accs[-1]), 4)) + '_acc.pth'

torch.save(model.state_dict(), fname)

print('Done!')

data = [train_losses, train_accs, val_losses, val_accs]

TMIDIX.Tegridy_Any_Pickle_File_Writer(data, '/content/losses_accuracies')
